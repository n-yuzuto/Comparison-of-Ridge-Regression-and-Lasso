# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv
# Out:
# --2021-06-02 17:10:00--  https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv
# archive.ics.uci.edu (archive.ics.uci.edu) をDNSに問いあわせています... 128.195.10.252
# archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443 に接続しています... 接続しました。
# HTTP による接続要求を送信しました、応答を待っています... 200 OK
# 長さ: 84199 (82K) [application/x-httpd-php]
# `winequality-red.csv.1' に保存中
#
# winequality-red.csv 100%[===================>]  82.23K   228KB/s 時間 0.4s
#
# 2021-06-02 17:10:01 (228 KB/s) - `winequality-red.csv.1' へ保存完了 [84199/84199]

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_validate
from sklearn.linear_model import Ridge
import io
import math


# データを読み込む
wine = pd.read_csv('winequality-red.csv', header=0,  sep=";")
featureName=['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
             'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 
             'pH', 'sulphates', 'alcohol']
objectiveName=['quality']

# 学習データを作る
sc = StandardScaler()
wine_except_quality = wine.drop("quality", axis=1)
X = wine_except_quality.values
X = sc.fit_transform(X)
y = wine['quality'].values

# 訓練用のデータを作る
X_train = X[:math.floor(len(y) * 0.75)]
y_train = y[:math.floor(len(y) * 0.75)]
m_train = len(y_train)            # 学習データの個数

# 評価用のデータを作る
X_test = X[math.floor(len(y) * 0.75)+1:]
y_test = y[math.floor(len(y) * 0.75)+1:]
m_test = len(y_test)            # 学習データの個数

# %% [markdown]
# # リッジ回帰について

# %%
# 正則化パラメータ
alphas = [2 ** c for c in range(-16, 12)]
summary = ""
results = []

for a in alphas:
    # 学習データで学習
    clf = Ridge(fit_intercept=True, normalize=False, copy_X=True, alpha=a)
    clf.fit(X_train, y_train)

    # 予測
    y_train_pred = clf.predict(X_train)
    y_test_pred = clf.predict(X_test)

    # 訓練誤差とテスト誤差
    train_MSE = mean_squared_error(y_train, y_train_pred, multioutput='uniform_average')
    test_MSE = mean_squared_error(y_test, y_test_pred, multioutput='uniform_average')

    # 予測精度
    result_string = f"alpha={a:10.5f}, Train MSE = {train_MSE:12.10f}, Test MSE = {test_MSE:12.10f}"
    summary += result_string + "\n"
    results.append((a, train_MSE, test_MSE))
    print("="*50)
    print(result_string)

    # model parameters
    print(pd.DataFrame({"Feature":wine_except_quality.columns,
                   "Coefficients":clf.coef_}).sort_values(by='Coefficients') )    
    
print('==SUMMARY==')
print(summary)
# Out:
# ==================================================
# alpha=   0.00002, Train MSE = 0.4071530532, Test MSE = 0.4588817895
#                  Feature  Coefficients
# 1       volatile acidity     -0.191309
# 6   total sulfur dioxide     -0.124909
# 4              chlorides     -0.075154
# 7                density     -0.074468
# 2            citric acid     -0.052329
# 8                     pH     -0.037902
# 5    free sulfur dioxide      0.036472
# 3         residual sugar      0.049296
# 0          fixed acidity      0.082719
# 9              sulphates      0.131130
# 10               alcohol      0.286977
# ==================================================
# alpha=   0.00003, Train MSE = 0.4071530532, Test MSE = 0.4588817893
#                  Feature  Coefficients
# 1       volatile acidity     -0.191309
# 6   total sulfur dioxide     -0.124909
# 4              chlorides     -0.075154
# 7                density     -0.074468
# 2            citric acid     -0.052329
# 8                     pH     -0.037902
# 5    free sulfur dioxide      0.036472
# 3         residual sugar      0.049296
# 0          fixed acidity      0.082719
# 9              sulphates      0.131130
# 10               alcohol      0.286977
# ==================================================
# alpha=   0.00006, Train MSE = 0.4071530532, Test MSE = 0.4588817888
#                  Feature  Coefficients
# 1       volatile acidity     -0.191309
# 6   total sulfur dioxide     -0.124909
# 4              chlorides     -0.075154
# 7                density     -0.074468
# 2            citric acid     -0.052329
# 8                     pH     -0.037902
# 5    free sulfur dioxide      0.036472
# 3         residual sugar      0.049296
# 0          fixed acidity      0.082719
# 9              sulphates      0.131130
# 10               alcohol      0.286977
# ==================================================
# alpha=   0.00012, Train MSE = 0.4071530532, Test MSE = 0.4588817878
#                  Feature  Coefficients
# 1       volatile acidity     -0.191309
# 6   total sulfur dioxide     -0.124909
# 4              chlorides     -0.075154
# 7                density     -0.074468
# 2            citric acid     -0.052329
# 8                     pH     -0.037902
# 5    free sulfur dioxide      0.036472
# 3         residual sugar      0.049296
# 0          fixed acidity      0.082719
# 9              sulphates      0.131130
# 10               alcohol      0.286977
# ==================================================
# alpha=   0.00024, Train MSE = 0.4071530532, Test MSE = 0.4588817857
#                  Feature  Coefficients
# 1       volatile acidity     -0.191309
# 6   total sulfur dioxide     -0.124909
# 4              chlorides     -0.075154
# 7                density     -0.074468
# 2            citric acid     -0.052329
# 8                     pH     -0.037902
# 5    free sulfur dioxide      0.036472
# 3         residual sugar      0.049296
# 0          fixed acidity      0.082719
# 9              sulphates      0.131130
# 10               alcohol      0.286977
# ==================================================
# alpha=   0.00049, Train MSE = 0.4071530532, Test MSE = 0.4588817817
#                  Feature  Coefficients
# 1       volatile acidity     -0.191309
# 6   total sulfur dioxide     -0.124909
# 4              chlorides     -0.075154
# 7                density     -0.074468
# 2            citric acid     -0.052329
# 8                     pH     -0.037902
# 5    free sulfur dioxide      0.036472
# 3         residual sugar      0.049296
# 0          fixed acidity      0.082719
# 9              sulphates      0.131130
# 10               alcohol      0.286977
# ==================================================
# alpha=   0.00098, Train MSE = 0.4071530532, Test MSE = 0.4588817737
#                  Feature  Coefficients
# 1       volatile acidity     -0.191309
# 6   total sulfur dioxide     -0.124909
# 4              chlorides     -0.075154
# 7                density     -0.074468
# 2            citric acid     -0.052328
# 8                     pH     -0.037902
# 5    free sulfur dioxide      0.036472
# 3         residual sugar      0.049296
# 0          fixed acidity      0.082719
# 9              sulphates      0.131130
# 10               alcohol      0.286977
# ==================================================
# alpha=   0.00195, Train MSE = 0.4071530532, Test MSE = 0.4588817576
#                  Feature  Coefficients
# 1       volatile acidity     -0.191308
# 6   total sulfur dioxide     -0.124909
# 4              chlorides     -0.075154
# 7                density     -0.074468
# 2            citric acid     -0.052328
# 8                     pH     -0.037902
# 5    free sulfur dioxide      0.036472
# 3         residual sugar      0.049296
# 0          fixed acidity      0.082719
# 9              sulphates      0.131130
# 10               alcohol      0.286977
# ==================================================
# alpha=   0.00391, Train MSE = 0.4071530532, Test MSE = 0.4588817254
#                  Feature  Coefficients
# 1       volatile acidity     -0.191308
# 6   total sulfur dioxide     -0.124909
# 4              chlorides     -0.075154
# 7                density     -0.074468
# 2            citric acid     -0.052327
# 8                     pH     -0.037901
# 5    free sulfur dioxide      0.036472
# 3         residual sugar      0.049296
# 0          fixed acidity      0.082719
# 9              sulphates      0.131130
# 10               alcohol      0.286976
# ==================================================
# alpha=   0.00781, Train MSE = 0.4071530532, Test MSE = 0.4588816610
#                  Feature  Coefficients
# 1       volatile acidity     -0.191307
# 6   total sulfur dioxide     -0.124909
# 4              chlorides     -0.075154
# 7                density     -0.074469
# 2            citric acid     -0.052325
# 8                     pH     -0.037901
# 5    free sulfur dioxide      0.036472
# 3         residual sugar      0.049296
# 0          fixed acidity      0.082718
# 9              sulphates      0.131130
# 10               alcohol      0.286975
# ==================================================
# alpha=   0.01562, Train MSE = 0.4071530533, Test MSE = 0.4588815322
#                  Feature  Coefficients
# 1       volatile acidity     -0.191305
# 6   total sulfur dioxide     -0.124908
# 4              chlorides     -0.075154
# 7                density     -0.074469
# 2            citric acid     -0.052322
# 8                     pH     -0.037900
# 5    free sulfur dioxide      0.036471
# 3         residual sugar      0.049295
# 0          fixed acidity      0.082717
# 9              sulphates      0.131129
# 10               alcohol      0.286973
# ==================================================
# alpha=   0.03125, Train MSE = 0.4071530534, Test MSE = 0.4588812748
#                  Feature  Coefficients
# 1       volatile acidity     -0.191301
# 6   total sulfur dioxide     -0.124907
# 4              chlorides     -0.075154
# 7                density     -0.074470
# 2            citric acid     -0.052315
# 8                     pH     -0.037898
# 5    free sulfur dioxide      0.036469
# 3         residual sugar      0.049295
# 0          fixed acidity      0.082714
# 9              sulphates      0.131128
# 10               alcohol      0.286968
# ==================================================
# alpha=   0.06250, Train MSE = 0.4071530538, Test MSE = 0.4588807601
#                  Feature  Coefficients
# 1       volatile acidity     -0.191293
# 6   total sulfur dioxide     -0.124905
# 4              chlorides     -0.075155
# 7                density     -0.074472
# 2            citric acid     -0.052301
# 8                     pH     -0.037895
# 5    free sulfur dioxide      0.036466
# 3         residual sugar      0.049294
# 0          fixed acidity      0.082708
# 9              sulphates      0.131126
# 10               alcohol      0.286960
# ==================================================
# alpha=   0.12500, Train MSE = 0.4071530557, Test MSE = 0.4588797316
#                  Feature  Coefficients
# 1       volatile acidity     -0.191277
# 6   total sulfur dioxide     -0.124901
# 4              chlorides     -0.075155
# 7                density     -0.074477
# 2            citric acid     -0.052272
# 8                     pH     -0.037889
# 5    free sulfur dioxide      0.036461
# 3         residual sugar      0.049293
# 0          fixed acidity      0.082697
# 9              sulphates      0.131121
# 10               alcohol      0.286942
# ==================================================
# alpha=   0.25000, Train MSE = 0.4071530630, Test MSE = 0.4588776785
#                  Feature  Coefficients
# 1       volatile acidity     -0.191245
# 6   total sulfur dioxide     -0.124893
# 4              chlorides     -0.075157
# 7                density     -0.074485
# 2            citric acid     -0.052216
# 8                     pH     -0.037876
# 5    free sulfur dioxide      0.036449
# 3         residual sugar      0.049290
# 0          fixed acidity      0.082675
# 9              sulphates      0.131112
# 10               alcohol      0.286907
# ==================================================
# alpha=   0.50000, Train MSE = 0.4071530923, Test MSE = 0.4588735873
#                  Feature  Coefficients
# 1       volatile acidity     -0.191181
# 6   total sulfur dioxide     -0.124877
# 4              chlorides     -0.075160
# 7                density     -0.074502
# 2            citric acid     -0.052103
# 8                     pH     -0.037850
# 5    free sulfur dioxide      0.036425
# 3         residual sugar      0.049283
# 0          fixed acidity      0.082631
# 9              sulphates      0.131093
# 10               alcohol      0.286838
# ==================================================
# alpha=   1.00000, Train MSE = 0.4071532090, Test MSE = 0.4588654647
#                  Feature  Coefficients
# 1       volatile acidity     -0.191053
# 6   total sulfur dioxide     -0.124845
# 4              chlorides     -0.075167
# 7                density     -0.074536
# 2            citric acid     -0.051878
# 8                     pH     -0.037798
# 5    free sulfur dioxide      0.036378
# 3         residual sugar      0.049271
# 0          fixed acidity      0.082544
# 9              sulphates      0.131055
# 10               alcohol      0.286699
# ==================================================
# alpha=   2.00000, Train MSE = 0.4071536737, Test MSE = 0.4588494571
#                  Feature  Coefficients
# 1       volatile acidity     -0.190799
# 6   total sulfur dioxide     -0.124781
# 4              chlorides     -0.075180
# 7                density     -0.074603
# 2            citric acid     -0.051431
# 8                     pH     -0.037695
# 5    free sulfur dioxide      0.036284
# 3         residual sugar      0.049245
# 0          fixed acidity      0.082370
# 9              sulphates      0.130979
# 10               alcohol      0.286422
# ==================================================
# alpha=   4.00000, Train MSE = 0.4071555137, Test MSE = 0.4588183790
#                  Feature  Coefficients
# 1       volatile acidity     -0.190296
# 6   total sulfur dioxide     -0.124651
# 4              chlorides     -0.075203
# 7                density     -0.074734
# 2            citric acid     -0.050547
# 8                     pH     -0.037491
# 5    free sulfur dioxide      0.036095
# 3         residual sugar      0.049194
# 0          fixed acidity      0.082026
# 9              sulphates      0.130827
# 10               alcohol      0.285874
# ==================================================
# alpha=   8.00000, Train MSE = 0.4071627284, Test MSE = 0.4587598687
#                  Feature  Coefficients
# 1       volatile acidity     -0.189310
# 6   total sulfur dioxide     -0.124384
# 4              chlorides     -0.075242
# 7                density     -0.074984
# 2            citric acid     -0.048818
# 8                     pH     -0.037089
# 5    free sulfur dioxide      0.035718
# 3         residual sugar      0.049087
# 0          fixed acidity      0.081351
# 9              sulphates      0.130520
# 10               alcohol      0.284793
# ==================================================
# alpha=  16.00000, Train MSE = 0.4071904941, Test MSE = 0.4586566666
#                  Feature  Coefficients
# 1       volatile acidity     -0.187414
# 6   total sulfur dioxide     -0.123826
# 7                density     -0.075440
# 4              chlorides     -0.075290
# 2            citric acid     -0.045514
# 8                     pH     -0.036312
# 5    free sulfur dioxide      0.034961
# 3         residual sugar      0.048859
# 0          fixed acidity      0.080058
# 9              sulphates      0.129898
# 10               alcohol      0.282697
# ==================================================
# alpha=  32.00000, Train MSE = 0.4072937704, Test MSE = 0.4585001539
#                  Feature  Coefficients
# 1       volatile acidity     -0.183894
# 6   total sulfur dioxide     -0.122638
# 7                density     -0.076198
# 4              chlorides     -0.075285
# 2            citric acid     -0.039454
# 8                     pH     -0.034857
# 5    free sulfur dioxide      0.033455
# 3         residual sugar      0.048362
# 0          fixed acidity      0.077667
# 9              sulphates      0.128630
# 10               alcohol      0.278734
# ==================================================
# alpha=  64.00000, Train MSE = 0.4076564423, Test MSE = 0.4583527600
#                  Feature  Coefficients
# 1       volatile acidity     -0.177736
# 6   total sulfur dioxide     -0.120092
# 7                density     -0.077231
# 4              chlorides     -0.074966
# 8                     pH     -0.032287
# 2            citric acid     -0.029137
# 5    free sulfur dioxide      0.030532
# 3         residual sugar      0.047255
# 0          fixed acidity      0.073536
# 9              sulphates      0.126044
# 10               alcohol      0.271555
# ==================================================
# alpha= 128.00000, Train MSE = 0.4088251535, Test MSE = 0.4585402247
#                  Feature  Coefficients
# 1       volatile acidity     -0.167876
# 6   total sulfur dioxide     -0.114875
# 7                density     -0.078054
# 4              chlorides     -0.073587
# 8                     pH     -0.028212
# 2            citric acid     -0.013626
# 5    free sulfur dioxide      0.025252
# 3         residual sugar      0.044875
# 0          fixed acidity      0.067108
# 9              sulphates      0.120902
# 10               alcohol      0.259310
# ==================================================
# alpha= 256.00000, Train MSE = 0.4122006977, Test MSE = 0.4600865134
#                  Feature  Coefficients
# 1       volatile acidity     -0.153656
# 6   total sulfur dioxide     -0.105393
# 7                density     -0.077295
# 4              chlorides     -0.069708
# 8                     pH     -0.022809
# 2            citric acid      0.005647
# 5    free sulfur dioxide      0.017051
# 3         residual sugar      0.040305
# 0          fixed acidity      0.058437
# 9              sulphates      0.111416
# 10               alcohol      0.239807
# ==================================================
# alpha= 512.00000, Train MSE = 0.4208203309, Test MSE = 0.4654223864
#                  Feature  Coefficients
# 1       volatile acidity     -0.134856
# 6   total sulfur dioxide     -0.091028
# 7                density     -0.072789
# 4              chlorides     -0.061777
# 8                     pH     -0.017288
# 5    free sulfur dioxide      0.007092
# 2            citric acid      0.023768
# 3         residual sugar      0.033051
# 0          fixed acidity      0.048437
# 9              sulphates      0.096200
# 10               alcohol      0.210887
# ==================================================
# alpha=1024.00000, Train MSE = 0.4398120666, Test MSE = 0.4788525044
#                  Feature  Coefficients
# 1       volatile acidity     -0.111337
# 6   total sulfur dioxide     -0.073005
# 7                density     -0.062766
# 4              chlorides     -0.049660
# 8                     pH     -0.013114
# 5    free sulfur dioxide     -0.001577
# 3         residual sugar      0.024006
# 2            citric acid      0.034521
# 0          fixed acidity      0.038310
# 9              sulphates      0.076021
# 10               alcohol      0.171895
# ==================================================
# alpha=2048.00000, Train MSE = 0.4738049402, Test MSE = 0.5045004511
#                  Feature  Coefficients
# 1       volatile acidity     -0.084116
# 6   total sulfur dioxide     -0.053678
# 7                density     -0.047867
# 4              chlorides     -0.035500
# 8                     pH     -0.010374
# 5    free sulfur dioxide     -0.006300
# 3         residual sugar      0.015328
# 0          fixed acidity      0.028748
# 2            citric acid      0.035051
# 9              sulphates      0.054294
# 10               alcohol      0.126572
# ==SUMMARY==
# alpha=   0.00002, Train MSE = 0.4071530532, Test MSE = 0.4588817895
# alpha=   0.00003, Train MSE = 0.4071530532, Test MSE = 0.4588817893
# alpha=   0.00006, Train MSE = 0.4071530532, Test MSE = 0.4588817888
# alpha=   0.00012, Train MSE = 0.4071530532, Test MSE = 0.4588817878
# alpha=   0.00024, Train MSE = 0.4071530532, Test MSE = 0.4588817857
# alpha=   0.00049, Train MSE = 0.4071530532, Test MSE = 0.4588817817
# alpha=   0.00098, Train MSE = 0.4071530532, Test MSE = 0.4588817737
# alpha=   0.00195, Train MSE = 0.4071530532, Test MSE = 0.4588817576
# alpha=   0.00391, Train MSE = 0.4071530532, Test MSE = 0.4588817254
# alpha=   0.00781, Train MSE = 0.4071530532, Test MSE = 0.4588816610
# alpha=   0.01562, Train MSE = 0.4071530533, Test MSE = 0.4588815322
# alpha=   0.03125, Train MSE = 0.4071530534, Test MSE = 0.4588812748
# alpha=   0.06250, Train MSE = 0.4071530538, Test MSE = 0.4588807601
# alpha=   0.12500, Train MSE = 0.4071530557, Test MSE = 0.4588797316
# alpha=   0.25000, Train MSE = 0.4071530630, Test MSE = 0.4588776785
# alpha=   0.50000, Train MSE = 0.4071530923, Test MSE = 0.4588735873
# alpha=   1.00000, Train MSE = 0.4071532090, Test MSE = 0.4588654647
# alpha=   2.00000, Train MSE = 0.4071536737, Test MSE = 0.4588494571
# alpha=   4.00000, Train MSE = 0.4071555137, Test MSE = 0.4588183790
# alpha=   8.00000, Train MSE = 0.4071627284, Test MSE = 0.4587598687
# alpha=  16.00000, Train MSE = 0.4071904941, Test MSE = 0.4586566666
# alpha=  32.00000, Train MSE = 0.4072937704, Test MSE = 0.4585001539
# alpha=  64.00000, Train MSE = 0.4076564423, Test MSE = 0.4583527600
# alpha= 128.00000, Train MSE = 0.4088251535, Test MSE = 0.4585402247
# alpha= 256.00000, Train MSE = 0.4122006977, Test MSE = 0.4600865134
# alpha= 512.00000, Train MSE = 0.4208203309, Test MSE = 0.4654223864
# alpha=1024.00000, Train MSE = 0.4398120666, Test MSE = 0.4788525044
# alpha=2048.00000, Train MSE = 0.4738049402, Test MSE = 0.5045004511

# %% [markdown]
# ### グラフ化

# %%
from matplotlib import pyplot as plt
# 見やすくするために最後の３つを表示していない
alphas, train_MSEs, test_MSEs = zip(*results[:-3])
plt.figure(figsize=(10,5))
plt.plot(alphas, test_MSEs, label="Test MSE")
plt.xscale('log', basex=2)
plt.legend()
plt.xlabel('alpha')
plt.ylabel('Test MSE')
plt.show()
# Out:
# <ipython-input-12-e78ae04aa1a1>:6: MatplotlibDeprecationWarning: The 'basex' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.xscale('log', basex=2)

# %% [markdown]
# # ラッソ回帰について

# %%
from sklearn.linear_model import Lasso

# %%
# 正則化パラメータ
alphas = [2 ** c for c in range(-16, 12)]
summary = ""
results = []

for a in alphas:
    # 学習データで学習
    clf = Lasso(fit_intercept=True, normalize=False, copy_X=True, alpha=a)
    clf.fit(X_train, y_train)

    # 予測
    y_train_pred = clf.predict(X_train)
    y_test_pred = clf.predict(X_test)

    # 訓練誤差とテスト誤差
    train_MSE = mean_squared_error(y_train, y_train_pred, multioutput='uniform_average')
    test_MSE = mean_squared_error(y_test, y_test_pred, multioutput='uniform_average')

    # 予測精度
    result_string = f"alpha={a:10.5f}, Train MSE = {train_MSE:12.10f}, Test MSE = {test_MSE:12.10f}"
    summary += result_string + "\n"
    results.append((a, train_MSE, test_MSE))
    print("="*50)
    print(result_string)

    # model parameters
    print(pd.DataFrame({"Feature":wine_except_quality.columns,
                   "Coefficients":clf.coef_}).sort_values(by='Coefficients') )    
    
print('==SUMMARY==')
print(summary)
# Out:
# ==================================================
# alpha=   0.00002, Train MSE = 0.4071530599, Test MSE = 0.4588726954
#                  Feature  Coefficients
# 1       volatile acidity     -0.191289
# 6   total sulfur dioxide     -0.124879
# 4              chlorides     -0.075150
# 7                density     -0.074360
# 2            citric acid     -0.052251
# 8                     pH     -0.037913
# 5    free sulfur dioxide      0.036435
# 3         residual sugar      0.049237
# 0          fixed acidity      0.082594
# 9              sulphates      0.131102
# 10               alcohol      0.287018
# ==================================================
# alpha=   0.00003, Train MSE = 0.4071530799, Test MSE = 0.4588635950
#                  Feature  Coefficients
# 1       volatile acidity     -0.191268
# 6   total sulfur dioxide     -0.124848
# 4              chlorides     -0.075146
# 7                density     -0.074252
# 2            citric acid     -0.052173
# 8                     pH     -0.037924
# 5    free sulfur dioxide      0.036398
# 3         residual sugar      0.049178
# 0          fixed acidity      0.082467
# 9              sulphates      0.131073
# 10               alcohol      0.287058
# ==================================================
# alpha=   0.00006, Train MSE = 0.4071531597, Test MSE = 0.4588454886
#                  Feature  Coefficients
# 1       volatile acidity     -0.191227
# 6   total sulfur dioxide     -0.124787
# 4              chlorides     -0.075139
# 7                density     -0.074037
# 2            citric acid     -0.052017
# 8                     pH     -0.037946
# 5    free sulfur dioxide      0.036324
# 3         residual sugar      0.049060
# 0          fixed acidity      0.082216
# 9              sulphates      0.131016
# 10               alcohol      0.287139
# ==================================================
# alpha=   0.00012, Train MSE = 0.4071534794, Test MSE = 0.4588093361
#                  Feature  Coefficients
# 1       volatile acidity     -0.191146
# 6   total sulfur dioxide     -0.124665
# 4              chlorides     -0.075125
# 7                density     -0.073605
# 2            citric acid     -0.051705
# 8                     pH     -0.037992
# 5    free sulfur dioxide      0.036176
# 3         residual sugar      0.048824
# 0          fixed acidity      0.081711
# 9              sulphates      0.130901
# 10               alcohol      0.287302
# ==================================================
# alpha=   0.00024, Train MSE = 0.4071547568, Test MSE = 0.4587379205
#                  Feature  Coefficients
# 1       volatile acidity     -0.190983
# 6   total sulfur dioxide     -0.124422
# 4              chlorides     -0.075095
# 7                density     -0.072744
# 2            citric acid     -0.051081
# 8                     pH     -0.038080
# 5    free sulfur dioxide      0.035880
# 3         residual sugar      0.048354
# 0          fixed acidity      0.080707
# 9              sulphates      0.130671
# 10               alcohol      0.287626
# ==================================================
# alpha=   0.00049, Train MSE = 0.4071598724, Test MSE = 0.4585973963
#                  Feature  Coefficients
# 1       volatile acidity     -0.190658
# 6   total sulfur dioxide     -0.123935
# 4              chlorides     -0.075038
# 7                density     -0.071015
# 2            citric acid     -0.049833
# 8                     pH     -0.038261
# 5    free sulfur dioxide      0.035288
# 3         residual sugar      0.047410
# 0          fixed acidity      0.078688
# 9              sulphates      0.130212
# 10               alcohol      0.288278
# ==================================================
# alpha=   0.00098, Train MSE = 0.4071803448, Test MSE = 0.4583270661
#                  Feature  Coefficients
# 1       volatile acidity     -0.190007
# 6   total sulfur dioxide     -0.122962
# 4              chlorides     -0.074923
# 7                density     -0.067555
# 2            citric acid     -0.047336
# 8                     pH     -0.038625
# 5    free sulfur dioxide      0.034105
# 3         residual sugar      0.045521
# 0          fixed acidity      0.074648
# 9              sulphates      0.129294
# 10               alcohol      0.289583
# ==================================================
# alpha=   0.00195, Train MSE = 0.4072628187, Test MSE = 0.4578227192
#                  Feature  Coefficients
# 1       volatile acidity     -0.188709
# 6   total sulfur dioxide     -0.121038
# 4              chlorides     -0.074717
# 7                density     -0.060490
# 2            citric acid     -0.042335
# 8                     pH     -0.039451
# 5    free sulfur dioxide      0.031758
# 3         residual sugar      0.041690
# 0          fixed acidity      0.066390
# 9              sulphates      0.127448
# 10               alcohol      0.292266
# ==================================================
# alpha=   0.00391, Train MSE = 0.4075935036, Test MSE = 0.4569882355
#                  Feature  Coefficients
# 1       volatile acidity     -0.186113
# 6   total sulfur dioxide     -0.117193
# 4              chlorides     -0.074310
# 7                density     -0.046339
# 8                     pH     -0.041118
# 2            citric acid     -0.032332
# 5    free sulfur dioxide      0.027067
# 3         residual sugar      0.034021
# 0          fixed acidity      0.049848
# 9              sulphates      0.123756
# 10               alcohol      0.297644
# ==================================================
# alpha=   0.00781, Train MSE = 0.4089173915, Test MSE = 0.4560211245
#                  Feature  Coefficients
# 1       volatile acidity     -0.180921
# 6   total sulfur dioxide     -0.109501
# 4              chlorides     -0.073494
# 8                     pH     -0.044440
# 7                density     -0.018053
# 2            citric acid     -0.012326
# 0          fixed acidity      0.016785
# 5    free sulfur dioxide      0.017682
# 3         residual sugar      0.018687
# 9              sulphates      0.116373
# 10               alcohol      0.308392
# ==================================================
# alpha=   0.01562, Train MSE = 0.4116334419, Test MSE = 0.4576384133
#                  Feature  Coefficients
# 1       volatile acidity     -0.177458
# 6   total sulfur dioxide     -0.090151
# 4              chlorides     -0.063845
# 8                     pH     -0.037025
# 0          fixed acidity      0.000000
# 2            citric acid     -0.000000
# 5    free sulfur dioxide      0.000000
# 7                density     -0.000000
# 3         residual sugar      0.001280
# 9              sulphates      0.104721
# 10               alcohol      0.314400
# ==================================================
# alpha=   0.03125, Train MSE = 0.4157006822, Test MSE = 0.4619881510
#                  Feature  Coefficients
# 1       volatile acidity     -0.174679
# 6   total sulfur dioxide     -0.075488
# 4              chlorides     -0.038556
# 8                     pH     -0.016630
# 2            citric acid      0.000000
# 3         residual sugar      0.000000
# 5    free sulfur dioxide      0.000000
# 7                density     -0.000000
# 0          fixed acidity      0.004708
# 9              sulphates      0.084794
# 10               alcohol      0.306866
# ==================================================
# alpha=   0.06250, Train MSE = 0.4290287914, Test MSE = 0.4739304515
#                  Feature  Coefficients
# 1       volatile acidity     -0.165273
# 6   total sulfur dioxide     -0.049432
# 0          fixed acidity      0.000000
# 2            citric acid      0.000000
# 3         residual sugar      0.000000
# 4              chlorides     -0.000000
# 5    free sulfur dioxide     -0.000000
# 7                density     -0.000000
# 8                     pH     -0.000000
# 9              sulphates      0.047751
# 10               alcohol      0.292371
# ==================================================
# alpha=   0.12500, Train MSE = 0.4613918455, Test MSE = 0.4996206759
#                  Feature  Coefficients
# 1       volatile acidity     -0.127965
# 0          fixed acidity      0.000000
# 2            citric acid      0.000000
# 3         residual sugar      0.000000
# 4              chlorides     -0.000000
# 5    free sulfur dioxide     -0.000000
# 6   total sulfur dioxide     -0.000000
# 7                density     -0.000000
# 8                     pH     -0.000000
# 9              sulphates      0.000000
# 10               alcohol      0.253935
# ==================================================
# alpha=   0.25000, Train MSE = 0.5370322649, Test MSE = 0.5662795492
#                  Feature  Coefficients
# 1       volatile acidity     -0.024116
# 0          fixed acidity      0.000000
# 2            citric acid      0.000000
# 3         residual sugar      0.000000
# 4              chlorides     -0.000000
# 5    free sulfur dioxide     -0.000000
# 6   total sulfur dioxide     -0.000000
# 7                density     -0.000000
# 8                     pH     -0.000000
# 9              sulphates      0.000000
# 10               alcohol      0.156075
# ==================================================
# alpha=   0.50000, Train MSE = 0.6548938127, Test MSE = 0.6469972787
#                  Feature  Coefficients
# 0          fixed acidity           0.0
# 1       volatile acidity          -0.0
# 2            citric acid           0.0
# 3         residual sugar           0.0
# 4              chlorides          -0.0
# 5    free sulfur dioxide          -0.0
# 6   total sulfur dioxide          -0.0
# 7                density          -0.0
# 8                     pH          -0.0
# 9              sulphates           0.0
# 10               alcohol           0.0
# ==================================================
# alpha=   1.00000, Train MSE = 0.6548938127, Test MSE = 0.6469972787
#                  Feature  Coefficients
# 0          fixed acidity           0.0
# 1       volatile acidity          -0.0
# 2            citric acid           0.0
# 3         residual sugar           0.0
# 4              chlorides          -0.0
# 5    free sulfur dioxide          -0.0
# 6   total sulfur dioxide          -0.0
# 7                density          -0.0
# 8                     pH          -0.0
# 9              sulphates           0.0
# 10               alcohol           0.0
# ==================================================
# alpha=   2.00000, Train MSE = 0.6548938127, Test MSE = 0.6469972787
#                  Feature  Coefficients
# 0          fixed acidity           0.0
# 1       volatile acidity          -0.0
# 2            citric acid           0.0
# 3         residual sugar           0.0
# 4              chlorides          -0.0
# 5    free sulfur dioxide          -0.0
# 6   total sulfur dioxide          -0.0
# 7                density          -0.0
# 8                     pH          -0.0
# 9              sulphates           0.0
# 10               alcohol           0.0
# ==================================================
# alpha=   4.00000, Train MSE = 0.6548938127, Test MSE = 0.6469972787
#                  Feature  Coefficients
# 0          fixed acidity           0.0
# 1       volatile acidity          -0.0
# 2            citric acid           0.0
# 3         residual sugar           0.0
# 4              chlorides          -0.0
# 5    free sulfur dioxide          -0.0
# 6   total sulfur dioxide          -0.0
# 7                density          -0.0
# 8                     pH          -0.0
# 9              sulphates           0.0
# 10               alcohol           0.0
# ==================================================
# alpha=   8.00000, Train MSE = 0.6548938127, Test MSE = 0.6469972787
#                  Feature  Coefficients
# 0          fixed acidity           0.0
# 1       volatile acidity          -0.0
# 2            citric acid           0.0
# 3         residual sugar           0.0
# 4              chlorides          -0.0
# 5    free sulfur dioxide          -0.0
# 6   total sulfur dioxide          -0.0
# 7                density          -0.0
# 8                     pH          -0.0
# 9              sulphates           0.0
# 10               alcohol           0.0
# ==================================================
# alpha=  16.00000, Train MSE = 0.6548938127, Test MSE = 0.6469972787
#                  Feature  Coefficients
# 0          fixed acidity           0.0
# 1       volatile acidity          -0.0
# 2            citric acid           0.0
# 3         residual sugar           0.0
# 4              chlorides          -0.0
# 5    free sulfur dioxide          -0.0
# 6   total sulfur dioxide          -0.0
# 7                density          -0.0
# 8                     pH          -0.0
# 9              sulphates           0.0
# 10               alcohol           0.0
# ==================================================
# alpha=  32.00000, Train MSE = 0.6548938127, Test MSE = 0.6469972787
#                  Feature  Coefficients
# 0          fixed acidity           0.0
# 1       volatile acidity          -0.0
# 2            citric acid           0.0
# 3         residual sugar           0.0
# 4              chlorides          -0.0
# 5    free sulfur dioxide          -0.0
# 6   total sulfur dioxide          -0.0
# 7                density          -0.0
# 8                     pH          -0.0
# 9              sulphates           0.0
# 10               alcohol           0.0
# ==================================================
# alpha=  64.00000, Train MSE = 0.6548938127, Test MSE = 0.6469972787
#                  Feature  Coefficients
# 0          fixed acidity           0.0
# 1       volatile acidity          -0.0
# 2            citric acid           0.0
# 3         residual sugar           0.0
# 4              chlorides          -0.0
# 5    free sulfur dioxide          -0.0
# 6   total sulfur dioxide          -0.0
# 7                density          -0.0
# 8                     pH          -0.0
# 9              sulphates           0.0
# 10               alcohol           0.0
# ==================================================
# alpha= 128.00000, Train MSE = 0.6548938127, Test MSE = 0.6469972787
#                  Feature  Coefficients
# 0          fixed acidity           0.0
# 1       volatile acidity          -0.0
# 2            citric acid           0.0
# 3         residual sugar           0.0
# 4              chlorides          -0.0
# 5    free sulfur dioxide          -0.0
# 6   total sulfur dioxide          -0.0
# 7                density          -0.0
# 8                     pH          -0.0
# 9              sulphates           0.0
# 10               alcohol           0.0
# ==================================================
# alpha= 256.00000, Train MSE = 0.6548938127, Test MSE = 0.6469972787
#                  Feature  Coefficients
# 0          fixed acidity           0.0
# 1       volatile acidity          -0.0
# 2            citric acid           0.0
# 3         residual sugar           0.0
# 4              chlorides          -0.0
# 5    free sulfur dioxide          -0.0
# 6   total sulfur dioxide          -0.0
# 7                density          -0.0
# 8                     pH          -0.0
# 9              sulphates           0.0
# 10               alcohol           0.0
# ==================================================
# alpha= 512.00000, Train MSE = 0.6548938127, Test MSE = 0.6469972787
#                  Feature  Coefficients
# 0          fixed acidity           0.0
# 1       volatile acidity          -0.0
# 2            citric acid           0.0
# 3         residual sugar           0.0
# 4              chlorides          -0.0
# 5    free sulfur dioxide          -0.0
# 6   total sulfur dioxide          -0.0
# 7                density          -0.0
# 8                     pH          -0.0
# 9              sulphates           0.0
# 10               alcohol           0.0
# ==================================================
# alpha=1024.00000, Train MSE = 0.6548938127, Test MSE = 0.6469972787
#                  Feature  Coefficients
# 0          fixed acidity           0.0
# 1       volatile acidity          -0.0
# 2            citric acid           0.0
# 3         residual sugar           0.0
# 4              chlorides          -0.0
# 5    free sulfur dioxide          -0.0
# 6   total sulfur dioxide          -0.0
# 7                density          -0.0
# 8                     pH          -0.0
# 9              sulphates           0.0
# 10               alcohol           0.0
# ==================================================
# alpha=2048.00000, Train MSE = 0.6548938127, Test MSE = 0.6469972787
#                  Feature  Coefficients
# 0          fixed acidity           0.0
# 1       volatile acidity          -0.0
# 2            citric acid           0.0
# 3         residual sugar           0.0
# 4              chlorides          -0.0
# 5    free sulfur dioxide          -0.0
# 6   total sulfur dioxide          -0.0
# 7                density          -0.0
# 8                     pH          -0.0
# 9              sulphates           0.0
# 10               alcohol           0.0
# ==SUMMARY==
# alpha=   0.00002, Train MSE = 0.4071530599, Test MSE = 0.4588726954
# alpha=   0.00003, Train MSE = 0.4071530799, Test MSE = 0.4588635950
# alpha=   0.00006, Train MSE = 0.4071531597, Test MSE = 0.4588454886
# alpha=   0.00012, Train MSE = 0.4071534794, Test MSE = 0.4588093361
# alpha=   0.00024, Train MSE = 0.4071547568, Test MSE = 0.4587379205
# alpha=   0.00049, Train MSE = 0.4071598724, Test MSE = 0.4585973963
# alpha=   0.00098, Train MSE = 0.4071803448, Test MSE = 0.4583270661
# alpha=   0.00195, Train MSE = 0.4072628187, Test MSE = 0.4578227192
# alpha=   0.00391, Train MSE = 0.4075935036, Test MSE = 0.4569882355
# alpha=   0.00781, Train MSE = 0.4089173915, Test MSE = 0.4560211245
# alpha=   0.01562, Train MSE = 0.4116334419, Test MSE = 0.4576384133
# alpha=   0.03125, Train MSE = 0.4157006822, Test MSE = 0.4619881510
# alpha=   0.06250, Train MSE = 0.4290287914, Test MSE = 0.4739304515
# alpha=   0.12500, Train MSE = 0.4613918455, Test MSE = 0.4996206759
# alpha=   0.25000, Train MSE = 0.5370322649, Test MSE = 0.5662795492
# alpha=   0.50000, Train MSE = 0.6548938127, Test MSE = 0.6469972787
# alpha=   1.00000, Train MSE = 0.6548938127, Test MSE = 0.6469972787
# alpha=   2.00000, Train MSE = 0.6548938127, Test MSE = 0.6469972787
# alpha=   4.00000, Train MSE = 0.6548938127, Test MSE = 0.6469972787
# alpha=   8.00000, Train MSE = 0.6548938127, Test MSE = 0.6469972787
# alpha=  16.00000, Train MSE = 0.6548938127, Test MSE = 0.6469972787
# alpha=  32.00000, Train MSE = 0.6548938127, Test MSE = 0.6469972787
# alpha=  64.00000, Train MSE = 0.6548938127, Test MSE = 0.6469972787
# alpha= 128.00000, Train MSE = 0.6548938127, Test MSE = 0.6469972787
# alpha= 256.00000, Train MSE = 0.6548938127, Test MSE = 0.6469972787
# alpha= 512.00000, Train MSE = 0.6548938127, Test MSE = 0.6469972787
# alpha=1024.00000, Train MSE = 0.6548938127, Test MSE = 0.6469972787
# alpha=2048.00000, Train MSE = 0.6548938127, Test MSE = 0.6469972787

# %% [markdown]
# ### グラフ化

# %%
from matplotlib import pyplot as plt
alphas, train_MSEs, test_MSEs = zip(*results)
plt.figure(figsize=(10,5))
plt.plot(alphas, test_MSEs, label="Test MSE")
plt.xscale('log', basex=2)
plt.legend()
plt.xlabel('alpha')
plt.ylabel('Test MSE')
plt.show()
# Out:
# <ipython-input-17-2de1677e1c82>:5: MatplotlibDeprecationWarning: The 'basex' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.xscale('log', basex=2)
